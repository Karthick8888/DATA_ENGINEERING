# %%
class sports():
    def __init__(self,brandcolor,cost):
        self.color = color
        self.brand = brand
        self.cost = cost
    def getColor(self):
        return self.color
    def setColor(self,color):
        self.color=color
    def setCost(self,cost):
        self.cost=cost
    def getCost(self):
        return self.cost
    def setBrand(self,brand):
        self.brand=brand
    def getBrand(self):
        return self.brand
class shoes(sports):
    def __init__(self,model,color,cost,brand):
        super.__init__(color,cost,brand)
        self.model=model
