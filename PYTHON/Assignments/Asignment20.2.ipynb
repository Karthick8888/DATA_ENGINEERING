# %% [markdown]
# 1.Create a file in dir put a file inside a dir and read data in dir,write data in dir and then delete dir

# %%
import os

os.getcwd()

os.chdir("C://Users//Administrator//Downloads//Data_Engineer//Python//Gopal//")

s=open("greetings.txt","w")

s.write("Hii Gopal \n")
s.write("Welcome")

s=open("greetings.txt","r")
s.read()

os.chdir("C://Users//Administrator//Downloads//Data_Engineer//Python//Gopal")
import shutil
s=open("greetings.txt","w")
s.close()

shutil.rmtree("C://Users//Administrator//Downloads//Data_Engineer//Python//Gopal") #permission error
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 import os
#       3 os.getcwd()
# ----> 5 os.chdir("C://Users//Administrator//Downloads//Data_Engineer//Python//Gopal//")
#       7 s=open("greetings.txt","w")
#       9 s.write("Hii Gopal \n")
#
# FileNotFoundError: [WinError 3] The system cannot find the path specified: 'C://Users//Administrator//Downloads//Data_Engineer//Python//Gopal//'
