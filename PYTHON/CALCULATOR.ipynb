# %%
class calc:
    def __init__(self):
        print("welcome Buudy....")
        print("Enjoy Calc....")
        self.setnum()
    def add(self):
        try:
            return self.num1+self.num2
        except Exception as e:
            print(e)
    def sub(self):
        try:
            return self.num1-self.num2
        except Exception as e:
            print(e)
    def mul(self):
        try:
            return self.num1*self.num2
        except Exception as e:
            print(e)
    def div(self):
        try:
            return self.num1/self.num2
        except Exception as e:
            print(e)
    def mod(self):
        try:
            return self.num1%self.num2
        except Exception as e:
            print(e)
    def setnum(self):
        
        self.num1=int(input("Enter the number 1"))
        self.num2=int(input("Enter the number 2"))
while True:
    print("1.ADD")
    print("2.SUB")
    print("3.MUL")
    print("4.DIV")
    print("5.MOD")
    print("6.EXIT")
    ch=int(input("Enter Choice First"))
    if ch==1 :
        a=calc()
        print(a.add())
    elif ch==2:
        a=calc()
        print(a.sub())
    elif ch==3:
        a=calc()
        print(a.mul())
    elif ch==4 :
        a=calc()
        print(a.div())
    elif ch==5:
        a=calc()
        print(a.mod())
    elif ch==6:
        print("WELCOME AGAIN")
        break
    else :
        print("Enter the Valid Option")
        continue
# Out:
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# 5.MOD
# 6.EXIT
# Enter Choice First 12
# Enter the Valid Option
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# 5.MOD
# 6.EXIT
# Enter Choice First 1
# welcome Buudy....
# Enjoy Calc....
# Enter the number 1 12
# Enter the number 2 12
# 24
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# 5.MOD
# 6.EXIT
# Enter Choice First 2
# welcome Buudy....
# Enjoy Calc....
# Enter the number 1 22
# Enter the number 2 24
# -2
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# 5.MOD
# 6.EXIT
# Enter Choice First 3
# welcome Buudy....
# Enjoy Calc....
# Enter the number 1 2
# Enter the number 2 5
# 10
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# 5.MOD
# 6.EXIT
# Enter Choice First 4
# welcome Buudy....
# Enjoy Calc....
# Enter the number 1 50
# Enter the number 2 5
# 10.0
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# 5.MOD
# 6.EXIT
# Enter Choice First 5
# welcome Buudy....
# Enjoy Calc....
# Enter the number 1 50
# Enter the number 2 3
# 2
# 1.ADD
# 2.SUB
# 3.MUL
# 4.DIV
# 5.MOD
# 6.EXIT
# Enter Choice First 6
