# %%
mydict = {1:'a',2:['b','c']}
print(mydict)
print(type(mydict))
# Out:
# {1: 'a', 2: ['b', 'c']}
# <class 'dict'>

# %%
mydict = dict([(1,'a'),(2,'b')])
print(id(mydict))
print(mydict.get(1))
# Out:
# 69210536
# a

# %%
co_vid = {1:'rajiv',2:'shyam'}
co_vid[3]='sam'
print(co_vid)
# Out:
# {1: 'rajiv', 2: 'shyam', 3: 'sam'}

# %%
co_vid = {1:'rajiv',2:'shyam'}
co_vid[3]='sam'
print(co_vid.pop(2))
# Out:
# shyam

# %%
co_vid = {1:'rajiv',2:'shyam'}
co_vid[3]='sam'
print(co_vid.popitem())
# Out:
# (3, 'sam')

# %%
squ = {2:4,3:9,4:16,5:25}
print(squ)
del squ[5]
print(squ)
# Out:
# {2: 4, 3: 9, 4: 16, 5: 25}
# {2: 4, 3: 9, 4: 16}

# %%
squ = {2:4,3:9,4:16,5:25}
print(squ)
squ.clear()
print(squ)
# Out:
# {2: 4, 3: 9, 4: 16, 5: 25}
# {}

# %%
squ ={2:4,3:9,4:16,5:25}
del squ
print(squ)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 squ ={2:4,3:9,4:16,5:25}
#       2 del squ
# ----> 3 print(squ)
#
# NameError: name 'squ' is not defined

# %%
co_vid ={1:'raviv',2:'shyam'}

co_vaxine = co_vid.copy()
print(co_vaxine)
print(co_vid)
print(type(co_vaxine))
print(type(co_vid))
print(id(co_vaxine))
print(id(co_vid))
# Out:
# {1: 'raviv', 2: 'shyam'}
# {1: 'raviv', 2: 'shyam'}
# <class 'dict'>
# <class 'dict'>
# 66656152
# 38335568

# %%
sub = dict.fromkeys(['math','English','hindi'],'0')
print(sub)
# Out:
# {'math': '0', 'English': '0', 'hindi': '0'}

# %%
squ = {2:4,3:9,4:16,5:25}
print(squ.items())
# Out:
# dict_items([(2, 4), (3, 9), (4, 16), (5, 25)])

# %%
squ = {2:4,3:9,4:16,5:25}
print(squ.keys())
# Out:
# dict_keys([2, 3, 4, 5])

# %%
squ = {2:4,3:9,4:16,5:25}
print(squ.values())
# Out:
# dict_values([4, 9, 16, 25])

# %%
lid = {}
print(dir(lid))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
squ = {2:4,3:9,4:16,5:25}
d_sq = {k:v for k,v in squ.items() if v>4}
print(d_sq)
# Out:
# {3: 9, 4: 16, 5: 25}

# %%
squ = {2:4,3:9,4:16,5:25}
d_sq = {k+5:v*2 for k,v in squ.items() if v>4}
print(d_sq)
# Out:
# {8: 18, 9: 32, 10: 50}
